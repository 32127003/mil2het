# %%
genept_emb_path ="/data2/project/bin_jip/Biomarker/data/gene_embedding/GenePT_gene_protein_embedding_model_3_text.pickle"
esm3_emb_path = "/data2/project/bin_jip/Biomarker/data/gene_embedding/ESM3_embeddings.pkl"
node2vec_emb_path = "/data2/project/bin_jip/Biomarker/data/gene_embedding/gene_node2vec_embeddings.pkl"

# %%
import pickle
with open(genept_emb_path, "rb") as f:
    genept_emb = pickle.load(f)
print(len(genept_emb))
with open(esm3_emb_path, "rb") as f:
    esm3_emb = pickle.load(f)
print(len(esm3_emb))
with open(node2vec_emb_path, "rb") as f:
    node2vec_emb = pickle.load(f)
print(len(node2vec_emb))
# Out:
# 133736
# 15377

# %%
genept_list = list(genept_emb.keys())
print(genept_list[:10])
genept_emb_vector = list(genept_emb.values())
print(genept_emb_vector[0])

esm3_list = list(esm3_emb.keys())
print(esm3_list[:10])
esm3_emb_vector = list(esm3_emb.values())
print(esm3_emb_vector[0])
# Out:
# ['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1', 'A2MP1', 'A3GALT2', 'A4GALT']
# ...

# %%
"""gene_emb의 구조를 알고 싶다. dictionary 맞는지 확인하는 코드"""
print(type(genept_emb))
print(type(genept_emb_vector))
print(len(genept_emb_vector))
print(type(genept_emb_vector[0]))
print(len(genept_emb_vector[0]))
print(genept_emb_vector[0][:10])  # 첫 번째 벡터의 처음 10개 요소 출력
# Out:
# <class 'dict'>
# <class 'list'>
# 133736
# <class 'list'>
# 3072
# [-0.012740327045321465, -0.01894552633166313, -0.00031466165091842413, -0.0022492262069135904, 0.0008057876257225871, -0.008889042772352695, 0.012873567640781403, -0.02154688909649849, 0.007848498411476612, -0.0006209957646206021]

# %%
print(type(esm3_emb))
print(type(esm3_emb_vector))
print(len(esm3_emb_vector))
print(type(esm3_emb_vector[0]))
print(len(esm3_emb_vector[0]))
print(esm3_emb_vector[0][:10])  # 첫 번째 벡터의
# Out:
# <class 'dict'>
# <class 'list'>
# 15377
# <class 'numpy.ndarray'>
# 1536
# [-200.72723   -45.429638  -52.121887   29.919075  -60.87198    96.8583
#   -43.178066  104.95139   -93.42291    27.789612]
