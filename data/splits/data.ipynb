# %%
import pickle
import os

# %%
path0='/data2/project/bin_jip/Biomarker/splits/aorta/aorta_fold_0.pkl'
path1='/data2/project/bin_jip/Biomarker/splits/aorta/aorta_fold_1.pkl'
with open(path0, 'rb') as f:
    data0 = pickle.load(f)
with open(path1, 'rb') as f:
    data1 = pickle.load(f)
#check if the splits are different
print(len(data0[0]),len(data0[1]),len(data0[2]))
print(len(data1[0]),len(data1[1]),len(data1[2]))
# Out:
# 7699 963 963
# 7699 963 963

# %%
path_0='/data2/project/bin_jip/Biomarker/splits/asthma/asthma_fold_0.pkl'
path_1='/data2/project/bin_jip/Biomarker/splits/asthma/asthma_fold_1.pkl'

# %%
with open(path_0, 'rb') as f:
    data_0 = pickle.load(f)
print(len(data_0[0]),len(data_0[1]),len(data_0[2]))
with open(path_1, 'rb') as f:
    data_1 = pickle.load(f)
print(len(data_1[0]),len(data_1[1]),len(data_1[2]))
print(data_0[0][:10],data_0[1][:10],data_0[2][:10])
# Out:
# 201427 25179 32946
# 201427 25179 32946
# [1, 2, 3, 4, 5, 6, 7, 9, 10, 12] [0, 8, 11, 33, 57, 65, 69, 74, 101, 113] [110806, 110807, 110808, 110809, 110810, 110811, 110812, 110813, 110814, 110815]
